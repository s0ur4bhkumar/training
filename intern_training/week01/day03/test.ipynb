# %%
import pandas as pd

df = pd.read_csv('hourly_prices.csv')
df
# Out:
#                timestamp  price
# 0   2025-09-30T00:00:00Z   38.4
# 1   2025-09-30T01:00:00Z   40.1
# 2   2025-09-30T02:00:00Z   42.7
# 3   2025-09-30T03:00:00Z   39.3
# 4   2025-09-30T04:00:00Z   37.8
# 5   2025-09-30T05:00:00Z   45.0
# 6   2025-09-30T06:00:00Z   52.2
# 7   2025-09-30T07:00:00Z   61.0
# 8   2025-09-30T08:00:00Z   58.5
# 9   2025-09-30T09:00:00Z   55.1
# 10  2025-09-30T10:00:00Z   49.6
# 11  2025-09-30T11:00:00Z   47.3
# 12  2025-09-30T12:00:00Z   46.0
# 13  2025-09-30T13:00:00Z   44.7
# 14  2025-09-30T14:00:00Z   50.8
# 15  2025-09-30T15:00:00Z   57.4
# 16  2025-09-30T16:00:00Z   60.2
# 17  2025-09-30T17:00:00Z   63.9
# 18  2025-09-30T18:00:00Z   59.7
# 19  2025-09-30T19:00:00Z   54.0
# 20  2025-09-30T20:00:00Z   50.2
# 21  2025-09-30T21:00:00Z   48.1
# 22  2025-09-30T22:00:00Z   44.9
# 23  2025-09-30T23:00:00Z   41.6

# %%
df.to_dict(orient='records')
# Out:
# [{'timestamp': '2025-09-30T00:00:00Z', 'price': 38.4},
#  {'timestamp': '2025-09-30T01:00:00Z', 'price': 40.1},
#  {'timestamp': '2025-09-30T02:00:00Z', 'price': 42.7},
#  {'timestamp': '2025-09-30T03:00:00Z', 'price': 39.3},
#  {'timestamp': '2025-09-30T04:00:00Z', 'price': 37.8},
#  {'timestamp': '2025-09-30T05:00:00Z', 'price': 45.0},
#  {'timestamp': '2025-09-30T06:00:00Z', 'price': 52.2},
#  {'timestamp': '2025-09-30T07:00:00Z', 'price': 61.0},
#  {'timestamp': '2025-09-30T08:00:00Z', 'price': 58.5},
#  {'timestamp': '2025-09-30T09:00:00Z', 'price': 55.1},
#  {'timestamp': '2025-09-30T10:00:00Z', 'price': 49.6},
#  {'timestamp': '2025-09-30T11:00:00Z', 'price': 47.3},
#  {'timestamp': '2025-09-30T12:00:00Z', 'price': 46.0},
#  {'timestamp': '2025-09-30T13:00:00Z', 'price': 44.7},
#  {'timestamp': '2025-09-30T14:00:00Z', 'price': 50.8},
#  {'timestamp': '2025-09-30T15:00:00Z', 'price': 57.4},
#  {'timestamp': '2025-09-30T16:00:00Z', 'price': 60.2},
# ...
